# %% [markdown]
# <a href="https://colab.research.google.com/github/nyantishedrick/diabetes-prediction-africa/blob/main/Copy_of_Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
print("My name is Shedrick Nyanti")
print("I am building a diabetes prediction system for Africa")
print("My mission starts today")
# Out:
# My name is Shedrick Nyanti
# I am building a diabetes prediction system for Africa
# My mission starts today

# %%
import pandas as pd
# Load directly from a reliable source
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv"

df = pd.read_csv(url, header=None)
# Add column names
df.columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreesFunction', 'Age ', 'Outcome' ]

print("Dataset loaded successfully")
print("Shape:", df.shape)
print(df.head())
# Out:
# Dataset loaded successfully
# Shape: (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreesFunction  Age   Outcome
# 0                      0.627    50        1
# 1                      0.351    31        0
# 2                      0.672    32        1
# 3                      0.167    21        0
# 4                      2.288    33        1
